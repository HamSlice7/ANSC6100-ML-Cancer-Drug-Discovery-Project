# %%
import pandas as pd
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit import Chem
data = pd.read_csv("for_fingerprint_visualization.csv")
mol = Chem.MolFromSmiles(data['canonical_smiles'][275])
bit_dict = {}
fpts =  AllChem.GetMorganFingerprintAsBitVect(mol,2,3072, bitInfo=bit_dict)
Draw.DrawMorganBit(mol, 343, bit_dict)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x7B522579CB50>

# %%
Draw.DrawMorganBit(mol, 1366, bit_dict)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x7B5276C3A0B0>
